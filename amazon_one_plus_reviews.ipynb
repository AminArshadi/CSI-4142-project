# %% [markdown]
# <a href="https://colab.research.google.com/github/AminArshadi/CSI-4142-project/blob/main/amazon_one_plus_reviews.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

amazon_one_plus_reviews_db = pd.read_json('https://query.data.world/s/eke656w4udxnc6v57negepzxrddrzw?dws=00000')
amazon_ecommerce_sample_db = pd.read_csv('https://query.data.world/s/kpd37xmqr3xrxjaodwjbo5deefywvo?dws=00000')

rows, columns = amazon_one_plus_reviews_db.shape

list(amazon_one_plus_reviews_db.columns)
# Out:
# ['product',
#  'product_company',
#  'profile_name',
#  'review_title',
#  'review_rating',
#  'review_text',
#  'helpful_count',
#  'total_comments',
#  'review_country',
#  'reviewed_at',
#  'url',
#  'crawled_at',
#  '_id',
#  'verified_purchase',
#  'color',
#  'style_name',
#  'size_name',
#  'category',
#  'sub_category',
#  'images']

# %%
amazon_one_plus_reviews_db.drop(['profile_name', 'total_comments', 'url', 'crawled_at', '_id', 'color', 'style_name', 'images', 'size_name'], axis=1, inplace=True)
amazon_one_plus_reviews_db
# Out:
#                                                  product product_company  \
# 0      OnePlus Nord 5G (Gray Onyx, 8GB RAM, 128GB Sto...         OnePlus
# 1      OnePlus Nord 5G (Gray Onyx, 8GB RAM, 128GB Sto...         OnePlus
# 2      OnePlus Nord 5G (Gray Onyx, 8GB RAM, 128GB Sto...         OnePlus
# 3      OnePlus Nord 5G (Gray Onyx, 8GB RAM, 128GB Sto...         OnePlus
# 4      OnePlus Nord 5G (Gray Onyx, 8GB RAM, 128GB Sto...         OnePlus
# ...                                                  ...             ...
# 30607  Redmi Note 9 Pro (Aurora Blue, 4GB RAM, 64GB S...           Redmi
# 30608  Redmi Note 9 Pro (Aurora Blue, 4GB RAM, 64GB S...           Redmi
# 30609  Redmi Note 9 Pro (Aurora Blue, 4GB RAM, 64GB S...           Redmi
# 30610  Redmi Note 9 Pro (Aurora Blue, 4GB RAM, 64GB S...           Redmi
# 30611  Redmi Note 9 Pro (Aurora Blue, 4GB RAM, 64GB S...           Redmi
#
#                                             review_title       review_rating  \
# 0                                *Read before you buy!!*  5.0 out of 5 stars
# 1                          Near to mid range  Perfection  5.0 out of 5 stars
# 2                                           Great price!  5.0 out of 5 stars
# 3                                      Beast in OnePlus.  5.0 out of 5 stars
# 4                                Changed to Nord from 6t  5.0 out of 5 stars
# ...                                                  ...                 ...
# 30607                     Great but not satisfied for me  2.0 out of 5 stars
# 30608                                      Not recommend  2.0 out of 5 stars
# 30609  WORST MARKETING TACTICS OF FLASH SALE OF REDMI...  2.0 out of 5 stars
# 30610                            Display retention issue  2.0 out of 5 stars
# 30611                            Camera quality is bad 👎  2.0 out of 5 stars
#
#                                              review_text  \
# 0      \n  Yea..pre-ordered on 28 July, got it on 4 A...
# 1      \n  Got it delivered yesterday , used for abou...
# 2                                  \n  An amazing phone!
# 3                                        \n  Brilliant..
# 4      \n  I was skeptical about changing from One pl...
# ...                                                  ...
# 30607  \n  Quality of phone is great but from my pers...
# 30608                                \n  Not recommend\n
# 30609  \n  Redmi and Amazon is engaged in a worst mar...
# 30610  \n  I am facing display retention problem, aft...
# 30611  \n  Front camera quality is worse as compare t...
#
#                        helpful_count review_country reviewed_at  \
# 0      721 people found this helpful         India   2020-08-04
# 1      436 people found this helpful         India   2020-08-03
# 2      322 people found this helpful         India   2020-08-04
# 3      243 people found this helpful         India   2020-08-02
# 4      109 people found this helpful         India   2020-08-04
# ...                              ...            ...         ...
# 30607                              0         India   2020-09-03
# 30608                              0         India   2020-05-20
# 30609    3 people found this helpful         India   2020-06-29
# 30610                              0         India   2020-04-26
# 30611                              0         India   2020-07-05
#
#        verified_purchase     category sub_category
# 0      Verified Purchase  electronics      mobiles
# 1      Verified Purchase  electronics      mobiles
# 2      Verified Purchase  electronics      mobiles
# 3      Verified Purchase  electronics      mobiles
# 4      Verified Purchase  electronics      mobiles
# ...                  ...          ...          ...
# 30607  Verified Purchase  electronics      mobiles
# 30608  Verified Purchase  electronics      mobiles
# 30609                 na  electronics      mobiles
# 30610                 na  electronics      mobiles
# 30611  Verified Purchase  electronics      mobiles
#
# [30612 rows x 11 columns]

# %%
for column_name in amazon_one_plus_reviews_db.columns.tolist():
  print(amazon_one_plus_reviews_db[column_name].isnull().any())
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False

# %%
for i in range(len(amazon_one_plus_reviews_db['product'])):
  amazon_one_plus_reviews_db['product'][i] = amazon_one_plus_reviews_db['product'][i].split('(')[0]

amazon_one_plus_reviews_db['product'] = amazon_one_plus_reviews_db['product'].astype(str)

amazon_one_plus_reviews_db
# Out:
# <ipython-input-42-611d76768ee6>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   amazon_one_plus_reviews_db['product'][i] = amazon_one_plus_reviews_db['product'][i].split('(')[0]
#                  product product_company  \
# 0       OnePlus Nord 5G          OnePlus
# 1       OnePlus Nord 5G          OnePlus
# 2       OnePlus Nord 5G          OnePlus
# 3       OnePlus Nord 5G          OnePlus
# 4       OnePlus Nord 5G          OnePlus
# ...                  ...             ...
# 30607  Redmi Note 9 Pro            Redmi
# 30608  Redmi Note 9 Pro            Redmi
# 30609  Redmi Note 9 Pro            Redmi
# 30610  Redmi Note 9 Pro            Redmi
# 30611  Redmi Note 9 Pro            Redmi
#
#                                             review_title       review_rating  \
# 0                                *Read before you buy!!*  5.0 out of 5 stars
# 1                          Near to mid range  Perfection  5.0 out of 5 stars
# 2                                           Great price!  5.0 out of 5 stars
# 3                                      Beast in OnePlus.  5.0 out of 5 stars
# 4                                Changed to Nord from 6t  5.0 out of 5 stars
# ...                                                  ...                 ...
# 30607                     Great but not satisfied for me  2.0 out of 5 stars
# 30608                                      Not recommend  2.0 out of 5 stars
# 30609  WORST MARKETING TACTICS OF FLASH SALE OF REDMI...  2.0 out of 5 stars
# 30610                            Display retention issue  2.0 out of 5 stars
# 30611                            Camera quality is bad 👎  2.0 out of 5 stars
#
#                                              review_text  \
# 0      \n  Yea..pre-ordered on 28 July, got it on 4 A...
# 1      \n  Got it delivered yesterday , used for abou...
# 2                                  \n  An amazing phone!
# 3                                        \n  Brilliant..
# 4      \n  I was skeptical about changing from One pl...
# ...                                                  ...
# 30607  \n  Quality of phone is great but from my pers...
# 30608                                \n  Not recommend\n
# 30609  \n  Redmi and Amazon is engaged in a worst mar...
# 30610  \n  I am facing display retention problem, aft...
# 30611  \n  Front camera quality is worse as compare t...
#
#                        helpful_count review_country reviewed_at  \
# 0      721 people found this helpful         India   2020-08-04
# 1      436 people found this helpful         India   2020-08-03
# 2      322 people found this helpful         India   2020-08-04
# 3      243 people found this helpful         India   2020-08-02
# 4      109 people found this helpful         India   2020-08-04
# ...                              ...            ...         ...
# 30607                              0         India   2020-09-03
# 30608                              0         India   2020-05-20
# 30609    3 people found this helpful         India   2020-06-29
# 30610                              0         India   2020-04-26
# 30611                              0         India   2020-07-05
#
#        verified_purchase     category sub_category
# 0      Verified Purchase  electronics      mobiles
# 1      Verified Purchase  electronics      mobiles
# 2      Verified Purchase  electronics      mobiles
# 3      Verified Purchase  electronics      mobiles
# 4      Verified Purchase  electronics      mobiles
# ...                  ...          ...          ...
# 30607  Verified Purchase  electronics      mobiles
# 30608  Verified Purchase  electronics      mobiles
# 30609                 na  electronics      mobiles
# 30610                 na  electronics      mobiles
# 30611  Verified Purchase  electronics      mobiles
#
# [30612 rows x 11 columns]

# %%
for i in range(len(amazon_one_plus_reviews_db['review_title'])):
  amazon_one_plus_reviews_db['review_title'][i] = amazon_one_plus_reviews_db['review_title'][i].strip()

amazon_one_plus_reviews_db['review_title'] = amazon_one_plus_reviews_db['review_title'].astype(str)

amazon_one_plus_reviews_db
# Out:
# <ipython-input-43-9481507a4bba>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   amazon_one_plus_reviews_db['review_title'][i] = amazon_one_plus_reviews_db['review_title'][i].strip()
#                  product product_company  \
# 0       OnePlus Nord 5G          OnePlus
# 1       OnePlus Nord 5G          OnePlus
# 2       OnePlus Nord 5G          OnePlus
# 3       OnePlus Nord 5G          OnePlus
# 4       OnePlus Nord 5G          OnePlus
# ...                  ...             ...
# 30607  Redmi Note 9 Pro            Redmi
# 30608  Redmi Note 9 Pro            Redmi
# 30609  Redmi Note 9 Pro            Redmi
# 30610  Redmi Note 9 Pro            Redmi
# 30611  Redmi Note 9 Pro            Redmi
#
#                                             review_title       review_rating  \
# 0                                *Read before you buy!!*  5.0 out of 5 stars
# 1                          Near to mid range  Perfection  5.0 out of 5 stars
# 2                                           Great price!  5.0 out of 5 stars
# 3                                      Beast in OnePlus.  5.0 out of 5 stars
# 4                                Changed to Nord from 6t  5.0 out of 5 stars
# ...                                                  ...                 ...
# 30607                     Great but not satisfied for me  2.0 out of 5 stars
# 30608                                      Not recommend  2.0 out of 5 stars
# 30609  WORST MARKETING TACTICS OF FLASH SALE OF REDMI...  2.0 out of 5 stars
# 30610                            Display retention issue  2.0 out of 5 stars
# 30611                            Camera quality is bad 👎  2.0 out of 5 stars
#
#                                              review_text  \
# 0      \n  Yea..pre-ordered on 28 July, got it on 4 A...
# 1      \n  Got it delivered yesterday , used for abou...
# 2                                  \n  An amazing phone!
# 3                                        \n  Brilliant..
# 4      \n  I was skeptical about changing from One pl...
# ...                                                  ...
# 30607  \n  Quality of phone is great but from my pers...
# 30608                                \n  Not recommend\n
# 30609  \n  Redmi and Amazon is engaged in a worst mar...
# 30610  \n  I am facing display retention problem, aft...
# 30611  \n  Front camera quality is worse as compare t...
#
#                        helpful_count review_country reviewed_at  \
# 0      721 people found this helpful         India   2020-08-04
# 1      436 people found this helpful         India   2020-08-03
# 2      322 people found this helpful         India   2020-08-04
# 3      243 people found this helpful         India   2020-08-02
# 4      109 people found this helpful         India   2020-08-04
# ...                              ...            ...         ...
# 30607                              0         India   2020-09-03
# 30608                              0         India   2020-05-20
# 30609    3 people found this helpful         India   2020-06-29
# 30610                              0         India   2020-04-26
# 30611                              0         India   2020-07-05
#
#        verified_purchase     category sub_category
# 0      Verified Purchase  electronics      mobiles
# 1      Verified Purchase  electronics      mobiles
# 2      Verified Purchase  electronics      mobiles
# 3      Verified Purchase  electronics      mobiles
# 4      Verified Purchase  electronics      mobiles
# ...                  ...          ...          ...
# 30607  Verified Purchase  electronics      mobiles
# 30608  Verified Purchase  electronics      mobiles
# 30609                 na  electronics      mobiles
# 30610                 na  electronics      mobiles
# 30611  Verified Purchase  electronics      mobiles
#
# [30612 rows x 11 columns]

# %%
for i in range(len(amazon_one_plus_reviews_db['review_rating'])):
  amazon_one_plus_reviews_db['review_rating'][i] = float(amazon_one_plus_reviews_db['review_rating'][i].split('out')[0])

amazon_one_plus_reviews_db['review_rating'] = amazon_one_plus_reviews_db['review_rating'].astype(float)

amazon_one_plus_reviews_db
# Out:
# <ipython-input-44-236243c8fb6b>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   amazon_one_plus_reviews_db['review_rating'][i] = float(amazon_one_plus_reviews_db['review_rating'][i].split('out')[0])
#                  product product_company  \
# 0       OnePlus Nord 5G          OnePlus
# 1       OnePlus Nord 5G          OnePlus
# 2       OnePlus Nord 5G          OnePlus
# 3       OnePlus Nord 5G          OnePlus
# 4       OnePlus Nord 5G          OnePlus
# ...                  ...             ...
# 30607  Redmi Note 9 Pro            Redmi
# 30608  Redmi Note 9 Pro            Redmi
# 30609  Redmi Note 9 Pro            Redmi
# 30610  Redmi Note 9 Pro            Redmi
# 30611  Redmi Note 9 Pro            Redmi
#
#                                             review_title  review_rating  \
# 0                                *Read before you buy!!*            5.0
# 1                          Near to mid range  Perfection            5.0
# 2                                           Great price!            5.0
# 3                                      Beast in OnePlus.            5.0
# 4                                Changed to Nord from 6t            5.0
# ...                                                  ...            ...
# 30607                     Great but not satisfied for me            2.0
# 30608                                      Not recommend            2.0
# 30609  WORST MARKETING TACTICS OF FLASH SALE OF REDMI...            2.0
# 30610                            Display retention issue            2.0
# 30611                            Camera quality is bad 👎            2.0
#
#                                              review_text  \
# 0      \n  Yea..pre-ordered on 28 July, got it on 4 A...
# 1      \n  Got it delivered yesterday , used for abou...
# 2                                  \n  An amazing phone!
# 3                                        \n  Brilliant..
# 4      \n  I was skeptical about changing from One pl...
# ...                                                  ...
# 30607  \n  Quality of phone is great but from my pers...
# 30608                                \n  Not recommend\n
# 30609  \n  Redmi and Amazon is engaged in a worst mar...
# 30610  \n  I am facing display retention problem, aft...
# 30611  \n  Front camera quality is worse as compare t...
#
#                        helpful_count review_country reviewed_at  \
# 0      721 people found this helpful         India   2020-08-04
# 1      436 people found this helpful         India   2020-08-03
# 2      322 people found this helpful         India   2020-08-04
# 3      243 people found this helpful         India   2020-08-02
# 4      109 people found this helpful         India   2020-08-04
# ...                              ...            ...         ...
# 30607                              0         India   2020-09-03
# 30608                              0         India   2020-05-20
# 30609    3 people found this helpful         India   2020-06-29
# 30610                              0         India   2020-04-26
# 30611                              0         India   2020-07-05
#
#        verified_purchase     category sub_category
# 0      Verified Purchase  electronics      mobiles
# 1      Verified Purchase  electronics      mobiles
# 2      Verified Purchase  electronics      mobiles
# 3      Verified Purchase  electronics      mobiles
# 4      Verified Purchase  electronics      mobiles
# ...                  ...          ...          ...
# 30607  Verified Purchase  electronics      mobiles
# 30608  Verified Purchase  electronics      mobiles
# 30609                 na  electronics      mobiles
# 30610                 na  electronics      mobiles
# 30611  Verified Purchase  electronics      mobiles
#
# [30612 rows x 11 columns]

# %%
for i in range(len(amazon_one_plus_reviews_db['review_text'])):
  amazon_one_plus_reviews_db['review_text'][i] = amazon_one_plus_reviews_db['review_text'][i].replace('\n', '')

amazon_one_plus_reviews_db['review_text'] = amazon_one_plus_reviews_db['review_text'].astype(str)

amazon_one_plus_reviews_db
# Out:
# <ipython-input-45-87c1c8b9efdf>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   amazon_one_plus_reviews_db['review_text'][i] = amazon_one_plus_reviews_db['review_text'][i].replace('\n', '')
#                  product product_company  \
# 0       OnePlus Nord 5G          OnePlus
# 1       OnePlus Nord 5G          OnePlus
# 2       OnePlus Nord 5G          OnePlus
# 3       OnePlus Nord 5G          OnePlus
# 4       OnePlus Nord 5G          OnePlus
# ...                  ...             ...
# 30607  Redmi Note 9 Pro            Redmi
# 30608  Redmi Note 9 Pro            Redmi
# 30609  Redmi Note 9 Pro            Redmi
# 30610  Redmi Note 9 Pro            Redmi
# 30611  Redmi Note 9 Pro            Redmi
#
#                                             review_title  review_rating  \
# 0                                *Read before you buy!!*            5.0
# 1                          Near to mid range  Perfection            5.0
# 2                                           Great price!            5.0
# 3                                      Beast in OnePlus.            5.0
# 4                                Changed to Nord from 6t            5.0
# ...                                                  ...            ...
# 30607                     Great but not satisfied for me            2.0
# 30608                                      Not recommend            2.0
# 30609  WORST MARKETING TACTICS OF FLASH SALE OF REDMI...            2.0
# 30610                            Display retention issue            2.0
# 30611                            Camera quality is bad 👎            2.0
#
#                                              review_text  \
# 0        Yea..pre-ordered on 28 July, got it on 4 Aug...
# 1        Got it delivered yesterday , used for about ...
# 2                                      An amazing phone!
# 3                                            Brilliant..
# 4        I was skeptical about changing from One plus...
# ...                                                  ...
# 30607    Quality of phone is great but from my perspe...
# 30608                                      Not recommend
# 30609    Redmi and Amazon is engaged in a worst marke...
# 30610    I am facing display retention problem, after...
# 30611    Front camera quality is worse as compare to ...
#
#                        helpful_count review_country reviewed_at  \
# 0      721 people found this helpful         India   2020-08-04
# 1      436 people found this helpful         India   2020-08-03
# 2      322 people found this helpful         India   2020-08-04
# 3      243 people found this helpful         India   2020-08-02
# 4      109 people found this helpful         India   2020-08-04
# ...                              ...            ...         ...
# 30607                              0         India   2020-09-03
# 30608                              0         India   2020-05-20
# 30609    3 people found this helpful         India   2020-06-29
# 30610                              0         India   2020-04-26
# 30611                              0         India   2020-07-05
#
#        verified_purchase     category sub_category
# 0      Verified Purchase  electronics      mobiles
# 1      Verified Purchase  electronics      mobiles
# 2      Verified Purchase  electronics      mobiles
# 3      Verified Purchase  electronics      mobiles
# 4      Verified Purchase  electronics      mobiles
# ...                  ...          ...          ...
# 30607  Verified Purchase  electronics      mobiles
# 30608  Verified Purchase  electronics      mobiles
# 30609                 na  electronics      mobiles
# 30610                 na  electronics      mobiles
# 30611  Verified Purchase  electronics      mobiles
#
# [30612 rows x 11 columns]

# %%
# !pip install word2number
# Out:
# Requirement already satisfied: word2number in /usr/local/lib/python3.10/dist-packages (1.1)

# %%
from word2number import w2n

for i in range(len(amazon_one_plus_reviews_db['helpful_count'])):
  new_value = amazon_one_plus_reviews_db['helpful_count'][i].split()[0].replace(',', '')

  try: # First, try to convert directly to int
      new_value = int(new_value)

  except ValueError: # If direct conversion fails, try to convert from words

      try:
          new_value = w2n.word_to_num(new_value)

      except ValueError: # If both conversions fail
          new_value = pd.NA

  amazon_one_plus_reviews_db['helpful_count'][i] = new_value

amazon_one_plus_reviews_db['helpful_count'] = amazon_one_plus_reviews_db['helpful_count'].astype(int)

amazon_one_plus_reviews_db
# Out:
# <ipython-input-47-531ac6c49443>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   amazon_one_plus_reviews_db['helpful_count'][i] = new_value
#                  product product_company  \
# 0       OnePlus Nord 5G          OnePlus
# 1       OnePlus Nord 5G          OnePlus
# 2       OnePlus Nord 5G          OnePlus
# 3       OnePlus Nord 5G          OnePlus
# 4       OnePlus Nord 5G          OnePlus
# ...                  ...             ...
# 30607  Redmi Note 9 Pro            Redmi
# 30608  Redmi Note 9 Pro            Redmi
# 30609  Redmi Note 9 Pro            Redmi
# 30610  Redmi Note 9 Pro            Redmi
# 30611  Redmi Note 9 Pro            Redmi
#
#                                             review_title  review_rating  \
# 0                                *Read before you buy!!*            5.0
# 1                          Near to mid range  Perfection            5.0
# 2                                           Great price!            5.0
# 3                                      Beast in OnePlus.            5.0
# 4                                Changed to Nord from 6t            5.0
# ...                                                  ...            ...
# 30607                     Great but not satisfied for me            2.0
# 30608                                      Not recommend            2.0
# 30609  WORST MARKETING TACTICS OF FLASH SALE OF REDMI...            2.0
# 30610                            Display retention issue            2.0
# 30611                            Camera quality is bad 👎            2.0
#
#                                              review_text  helpful_count  \
# 0        Yea..pre-ordered on 28 July, got it on 4 Aug...            721
# 1        Got it delivered yesterday , used for about ...            436
# 2                                      An amazing phone!            322
# 3                                            Brilliant..            243
# 4        I was skeptical about changing from One plus...            109
# ...                                                  ...            ...
# 30607    Quality of phone is great but from my perspe...              0
# 30608                                      Not recommend              0
# 30609    Redmi and Amazon is engaged in a worst marke...              3
# 30610    I am facing display retention problem, after...              0
# 30611    Front camera quality is worse as compare to ...              0
#
#       review_country reviewed_at  verified_purchase     category sub_category
# 0             India   2020-08-04  Verified Purchase  electronics      mobiles
# 1             India   2020-08-03  Verified Purchase  electronics      mobiles
# 2             India   2020-08-04  Verified Purchase  electronics      mobiles
# 3             India   2020-08-02  Verified Purchase  electronics      mobiles
# 4             India   2020-08-04  Verified Purchase  electronics      mobiles
# ...              ...         ...                ...          ...          ...
# 30607         India   2020-09-03  Verified Purchase  electronics      mobiles
# 30608         India   2020-05-20  Verified Purchase  electronics      mobiles
# 30609         India   2020-06-29                 na  electronics      mobiles
# 30610         India   2020-04-26                 na  electronics      mobiles
# 30611         India   2020-07-05  Verified Purchase  electronics      mobiles
#
# [30612 rows x 11 columns]

# %%
for i in range(len(amazon_one_plus_reviews_db['review_country'])):
  amazon_one_plus_reviews_db['review_country'][i] = amazon_one_plus_reviews_db['review_country'][i].strip()

amazon_one_plus_reviews_db['review_country'] = amazon_one_plus_reviews_db['review_country'].astype(str)

amazon_one_plus_reviews_db
# Out:
# <ipython-input-48-d33a8f408f29>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   amazon_one_plus_reviews_db['review_country'][i] = amazon_one_plus_reviews_db['review_country'][i].strip()
#                  product product_company  \
# 0       OnePlus Nord 5G          OnePlus
# 1       OnePlus Nord 5G          OnePlus
# 2       OnePlus Nord 5G          OnePlus
# 3       OnePlus Nord 5G          OnePlus
# 4       OnePlus Nord 5G          OnePlus
# ...                  ...             ...
# 30607  Redmi Note 9 Pro            Redmi
# 30608  Redmi Note 9 Pro            Redmi
# 30609  Redmi Note 9 Pro            Redmi
# 30610  Redmi Note 9 Pro            Redmi
# 30611  Redmi Note 9 Pro            Redmi
#
#                                             review_title  review_rating  \
# 0                                *Read before you buy!!*            5.0
# 1                          Near to mid range  Perfection            5.0
# 2                                           Great price!            5.0
# 3                                      Beast in OnePlus.            5.0
# 4                                Changed to Nord from 6t            5.0
# ...                                                  ...            ...
# 30607                     Great but not satisfied for me            2.0
# 30608                                      Not recommend            2.0
# 30609  WORST MARKETING TACTICS OF FLASH SALE OF REDMI...            2.0
# 30610                            Display retention issue            2.0
# 30611                            Camera quality is bad 👎            2.0
#
#                                              review_text  helpful_count  \
# 0        Yea..pre-ordered on 28 July, got it on 4 Aug...            721
# 1        Got it delivered yesterday , used for about ...            436
# 2                                      An amazing phone!            322
# 3                                            Brilliant..            243
# 4        I was skeptical about changing from One plus...            109
# ...                                                  ...            ...
# 30607    Quality of phone is great but from my perspe...              0
# 30608                                      Not recommend              0
# 30609    Redmi and Amazon is engaged in a worst marke...              3
# 30610    I am facing display retention problem, after...              0
# 30611    Front camera quality is worse as compare to ...              0
#
#       review_country reviewed_at  verified_purchase     category sub_category
# 0              India  2020-08-04  Verified Purchase  electronics      mobiles
# 1              India  2020-08-03  Verified Purchase  electronics      mobiles
# 2              India  2020-08-04  Verified Purchase  electronics      mobiles
# 3              India  2020-08-02  Verified Purchase  electronics      mobiles
# 4              India  2020-08-04  Verified Purchase  electronics      mobiles
# ...              ...         ...                ...          ...          ...
# 30607          India  2020-09-03  Verified Purchase  electronics      mobiles
# 30608          India  2020-05-20  Verified Purchase  electronics      mobiles
# 30609          India  2020-06-29                 na  electronics      mobiles
# 30610          India  2020-04-26                 na  electronics      mobiles
# 30611          India  2020-07-05  Verified Purchase  electronics      mobiles
#
# [30612 rows x 11 columns]

# %%
for i in range(len(amazon_one_plus_reviews_db['verified_purchase'])):
  current_value = amazon_one_plus_reviews_db['verified_purchase'][i]

  if current_value == 'na':
    amazon_one_plus_reviews_db['verified_purchase'][i] = 0
  else:
    amazon_one_plus_reviews_db['verified_purchase'][i] = 1

amazon_one_plus_reviews_db['verified_purchase'] = amazon_one_plus_reviews_db['verified_purchase'].astype(int)

amazon_one_plus_reviews_db
# Out:
# <ipython-input-49-0d630dcb541c>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   amazon_one_plus_reviews_db['verified_purchase'][i] = 1
# <ipython-input-49-0d630dcb541c>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   amazon_one_plus_reviews_db['verified_purchase'][i] = 0
#                  product product_company  \
# 0       OnePlus Nord 5G          OnePlus
# 1       OnePlus Nord 5G          OnePlus
# 2       OnePlus Nord 5G          OnePlus
# 3       OnePlus Nord 5G          OnePlus
# 4       OnePlus Nord 5G          OnePlus
# ...                  ...             ...
# 30607  Redmi Note 9 Pro            Redmi
# 30608  Redmi Note 9 Pro            Redmi
# 30609  Redmi Note 9 Pro            Redmi
# 30610  Redmi Note 9 Pro            Redmi
# 30611  Redmi Note 9 Pro            Redmi
#
#                                             review_title  review_rating  \
# 0                                *Read before you buy!!*            5.0
# 1                          Near to mid range  Perfection            5.0
# 2                                           Great price!            5.0
# 3                                      Beast in OnePlus.            5.0
# 4                                Changed to Nord from 6t            5.0
# ...                                                  ...            ...
# 30607                     Great but not satisfied for me            2.0
# 30608                                      Not recommend            2.0
# 30609  WORST MARKETING TACTICS OF FLASH SALE OF REDMI...            2.0
# 30610                            Display retention issue            2.0
# 30611                            Camera quality is bad 👎            2.0
#
#                                              review_text  helpful_count  \
# 0        Yea..pre-ordered on 28 July, got it on 4 Aug...            721
# 1        Got it delivered yesterday , used for about ...            436
# 2                                      An amazing phone!            322
# 3                                            Brilliant..            243
# 4        I was skeptical about changing from One plus...            109
# ...                                                  ...            ...
# 30607    Quality of phone is great but from my perspe...              0
# 30608                                      Not recommend              0
# 30609    Redmi and Amazon is engaged in a worst marke...              3
# 30610    I am facing display retention problem, after...              0
# 30611    Front camera quality is worse as compare to ...              0
#
#       review_country reviewed_at  verified_purchase     category sub_category
# 0              India  2020-08-04                  1  electronics      mobiles
# 1              India  2020-08-03                  1  electronics      mobiles
# 2              India  2020-08-04                  1  electronics      mobiles
# 3              India  2020-08-02                  1  electronics      mobiles
# 4              India  2020-08-04                  1  electronics      mobiles
# ...              ...         ...                ...          ...          ...
# 30607          India  2020-09-03                  1  electronics      mobiles
# 30608          India  2020-05-20                  1  electronics      mobiles
# 30609          India  2020-06-29                  0  electronics      mobiles
# 30610          India  2020-04-26                  0  electronics      mobiles
# 30611          India  2020-07-05                  1  electronics      mobiles
#
# [30612 rows x 11 columns]

# %%
amazon_one_plus_reviews_db.dtypes
# Out:
# product                      object
# product_company              object
# review_title                 object
# review_rating               float64
# review_text                  object
# helpful_count                 int64
# review_country               object
# reviewed_at          datetime64[ns]
# verified_purchase             int64
# category                     object
# sub_category                 object
# dtype: object

# %%
review_descripiton = []
for i in range(len(amazon_one_plus_reviews_db['review_title'])):
  review_title_elem = amazon_one_plus_reviews_db['review_title'][i]
  review_text_elem = amazon_one_plus_reviews_db['review_text'][i]
  new_elem = f'<t>{review_title_elem}</t><b>{review_text_elem}</b>' # t -> title | b -> body
  review_descripiton.append(new_elem)

amazon_one_plus_reviews_db['review_descripiton'] = review_descripiton

amazon_one_plus_reviews_db.drop(['review_title', 'review_text'], axis=1, inplace=True)

amazon_one_plus_reviews_db
# Out:
#                  product product_company  review_rating  helpful_count  \
# 0       OnePlus Nord 5G          OnePlus            5.0            721
# 1       OnePlus Nord 5G          OnePlus            5.0            436
# 2       OnePlus Nord 5G          OnePlus            5.0            322
# 3       OnePlus Nord 5G          OnePlus            5.0            243
# 4       OnePlus Nord 5G          OnePlus            5.0            109
# ...                  ...             ...            ...            ...
# 30607  Redmi Note 9 Pro            Redmi            2.0              0
# 30608  Redmi Note 9 Pro            Redmi            2.0              0
# 30609  Redmi Note 9 Pro            Redmi            2.0              3
# 30610  Redmi Note 9 Pro            Redmi            2.0              0
# 30611  Redmi Note 9 Pro            Redmi            2.0              0
#
#       review_country reviewed_at  verified_purchase     category sub_category  \
# 0              India  2020-08-04                  1  electronics      mobiles
# 1              India  2020-08-03                  1  electronics      mobiles
# 2              India  2020-08-04                  1  electronics      mobiles
# 3              India  2020-08-02                  1  electronics      mobiles
# 4              India  2020-08-04                  1  electronics      mobiles
# ...              ...         ...                ...          ...          ...
# 30607          India  2020-09-03                  1  electronics      mobiles
# 30608          India  2020-05-20                  1  electronics      mobiles
# 30609          India  2020-06-29                  0  electronics      mobiles
# 30610          India  2020-04-26                  0  electronics      mobiles
# 30611          India  2020-07-05                  1  electronics      mobiles
#
#                                       review_descripiton
# 0      <t>*Read before you buy!!*</t><b>  Yea..pre-or...
# 1      <t>Near to mid range  Perfection</t><b>  Got i...
# 2          <t>Great price!</t><b>  An amazing phone!</b>
# 3           <t>Beast in OnePlus.</t><b>  Brilliant..</b>
# 4      <t>Changed to Nord from 6t</t><b>  I was skept...
# ...                                                  ...
# 30607  <t>Great but not satisfied for me</t><b>  Qual...
# 30608         <t>Not recommend</t><b>  Not recommend</b>
# 30609  <t>WORST MARKETING TACTICS OF FLASH SALE OF RE...
# 30610  <t>Display retention issue</t><b>  I am facing...
# 30611  <t>Camera quality is bad 👎</t><b>  Front camer...
#
# [30612 rows x 10 columns]
